# %%
import time
import pandas as pd
import numpy as np
from datetime import datetime
from dateutil.parser import parse
from datetime import timedelta

# %%
CITY_DATA = { 'chicago': 'chicago.csv',
              'new york city': 'new_york_city.csv',
              'washington': 'washington.csv' }

# %%
def get_filters():
    """
    Asks user to specify a city, month, and day to analyze.

    Returns:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    """
    print("Hello! Lets explore some us bikeshare data!")
    a =True

    while a==True:
      city =input("\nWould you like to see data for chicago, new york city or washington ?  \n")
      city=city.lower()

      if city=='chicago'or  city=='new york city' or city=='washington' :

        while a==True :
          key=input("\nWould you like to filter the data by month, day or both\n")
          key=key.lower()

          if key=='month':
            while a==True:
              month =input("\nWhich month ? January, February, March, April, May or June\n")
              month=month.lower()

              if month=='january'or month=='february'or month=='march'or month=='april'or month=='may'or month=='june':
                a=False
                month='unknown'
                return city, month, day
              else :
                print("\nPlease enter the right month\n")
                a=True

          elif key=='day':

            while a==True:
              day =input("/nWhich day?  Monday, Tuesday, wendesday, Thursday, Friday, Saturday or Sunday     \n")
              day=day.lower()

              if  day=='monday'or day=='tuesday'or day=='wendesday' or day=='thursday'or day=='friday'or day=='saturday' or day=='sunday':
                a=False
                month='unknown'
                return city, month, day

              else :
                print("\nPlease enter your right day\n")
                a=True

          elif key=='both' :

            while a==True:
              month =input("\nWhich month ? january, february, march, april, may, june\n")
              month=month.lower()

              if month=='january'or month=='february'or month=='march'or month=='april'or month=='may'or month=='june':

                while a== True:
                  day =input("\nWhich day ? Monday, Tuesday, Wendesday, Thursday, Friday, Saturday or Sunday    \n")
                  day=day.lower()
                  if day=='monday'or day=='tuesday'or day=='wendesday' or day=='thursday'or day=='friday'or day=='saturday' or day=='sunday':
                    a=False
                    return city, month, day

                  else :
                    print("\nPlease enter the right day\n")
                    a=True


              else :
                print("\nPlease enter the right month\n")
                a=True

          else:
            print("\nWrong answer\n")

      else:
        print("\nWrong city, Please enter the right city\n")
        a=True


    # get user input for month (all, january, february, ... , june)


    # get user input for day of week (all, monday, tuesday, ... sunday)


    print('-'*40)

    exit()

# %%
import random
def load_data(city, month, day):
    """
    Loads data for the specified city and filters by month and day if applicable.

    Args:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    Returns:
        df - Pandas DataFrame containing city data filtered by month and day
    """

    df = pd.read_csv(CITY_DATA[city])
    dfwith = pd.read_csv(CITY_DATA[city])
    if month!='unknown' and day!='unknown':
     if city!='washington':
       df['Start Time']=pd.to_datetime(df['Start Time'])
       df['month']=df['Start Time'].dt.month
       df['day']=df['Start Time'].dt.day
       df['hour']=df['Start Time'].dt.hour
       df['day_week']=df['Start Time'].dt.dayofweek
       days = ['monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday']
       df['dayName']=df['day_week'].map(lambda x: days[x])

       Monthes={'january':1,'february':2,'march':3,'april':4,'may':5,'june':6}

       df[df['month']==Monthes[month]]
       df[df['dayName']==day]
       return df

     else:
       df['Start Time']=pd.to_datetime(df['Start Time'])
       df['month']=df['Start Time'].dt.month
       df['day']=df['Start Time'].dt.day
       df['hour']=df['Start Time'].dt.hour
       df['day_week']=df['Start Time'].dt.dayofweek
       days = ['monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday']
       df['dayName']=df['day_week'].map(lambda x: days[x])

       Monthes={'january':1,'february':2,'march':3,'april':4,'may':5,'june':6}

       df[df['month']==Monthes[month]]
       df[df['dayName']==day]
       return df
     #--------------------------------------------------------------------------------------------------

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
def time_stats(df):
    """Displays statistics on the most frequent times of travel."""

    # display the most common month


    # display the most common day of week


    # display the most common start hour


    start_time = time.time()

    df['Start Time']=pd.to_datetime(df['Start Time'])
    df['month']=df['Start Time'].dt.month
    df['day']=df['Start Time'].dt.day
    df['hour']=df['Start Time'].dt.hour
    df['day_week']=df['Start Time'].dt.dayofweek
    days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
    df['dayName']=df['day_week'].map(lambda x: days[x])

    #Monthes={'January':1,'February':2,'March':3,'April':4,'May':5,'June':6}
    Monthes={'january':1,'february':2,'march':3,'april':4,'may':5,'june':6}

    df[df['month']==Monthes[month]]
    df[df['dayName']==day]


    max_month =df['month'].value_counts().idxmax()
    max_day =df['dayName'].value_counts().idxmax()
    max_hour =df['hour'].value_counts().idxmax()
    print("Calculating The Most Frequent Times of Travel...")
    print("")
    print("month:",max_month)
    print("Day:",max_day)
    print("Hour:",max_hour)

    end_time = time.time()

    execution_time = end_time - start_time

    print('\nThis took '+str(execution_time)+' seconds')

    print('-'*40)
    print('شركات بكر والبرازيلي تتمني لكم صوما مقبولا وافطارا شهيا')
    print('مع تحيات بنك مصر انت تقدر')
    print('-'*40)

# %%
def station_stats(df):
    """Displays statistics on the most popular stations and trip."""
    start_time = time.time()


    max_start =df['Start Station'].value_counts().idxmax()
    max_end =df['End Station'].value_counts().idxmax()
    df['empty'] = '  '
    df['max_trip'] =df['Start Station']+df['empty']+ df['End Station']
    max_trip=df['max_trip'].value_counts().idxmax()
    print("Calcuating The Most Popular Stations and Trip")
    print(" ")
    print("Start Station: " + max_start)
    print("End Station: " + max_end)
    print(" ")
    print(" Start Station               End Station")
    print(max_trip)

    end_time = time.time()

    execution_time = end_time - start_time

    print('\nThis took '+str(execution_time)+' seconds')

    # display most commonly used start station


    # display most commonly used end station


    # display most frequent combination of start station and end station trip


    print('-'*40)

# %%
def trip_duration_stats(df):
    """Displays statistics on the total and average trip duration."""

    start_time = time.time()


    print('Calculating Trip Duration...')

    total_travel_time=df['Trip Duration'].sum()

    print('\nTotal Travel Duration:  '+str(total_travel_time/60))


    # display mean travel time

    mean_travel_time = df['Trip Duration'].mean()
    print('\nAverage Travel Time ' + str(mean_travel_time))

    end_time = time.time()

    execution_time = end_time - start_time

    print('\nThis took '+str(execution_time)+' seconds')

    print('-'*40)

# %%
def user_stats(df,city):
    """Displays statistics on bikeshare users."""
    if city=="washington":
      print('UnKnown')
    else:
    # Display counts of user types
      start_time = time.time()


      Subscriber=df['User Type'].value_counts()['Subscriber']
      Customer=df['User Type'].value_counts()['Customer']

      print("Subscriber     "+str(Subscriber))
      print("Customer       "+str(Customer))

    # Display counts of gender
      Male=df['Gender'].value_counts()['Male']
      Female=df['Gender'].value_counts()['Female']
      print("Male     "+str(Male))



      now = datetime.now()
      df['Age']=now.year-df['Birth Year']


      Oldest=df['Age'].min()
      print('Most recent year of birth: '+str(Oldest))

      Earlist=df['Age'].max()
      print('Earlist year of birth: '+str(Earlist))


      commun=df['Age'].value_counts().idxmax()
      print('Most commun year of birth: '+str(commun))

      end_time = time.time()

      execution_time = end_time - start_time

      print('This took '+str(execution_time)+' seconds')


      print('-'*40)

# %%
def main():


    while True:

        city, month, day = get_filters()
        df = load_data(city, month, day)

        time_stats(df)
        station_stats(df)
        trip_duration_stats(df)
        user_stats(df,city)

        restart = input('\nWould you like to restart? Enter yes or no.\n')
        if restart.lower() != 'yes':
            break

# %%
if __name__ == "__main__":
	main()
# Out:
# Hello! Lets explore some us bikeshare data!
#
# Would you like to see data for chicago, new york city or washington ?
# chicago
#
# Would you like to filter the data by month, day or both
# both
#
# Which month ? january, february, march, april, may, june
# may
#
# Which day ? Monday, Tuesday, Wendesday, Thursday, Friday, Saturday or Sunday
# monday
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-cc5a1e70fb89> in <cell line: 1>()
#       1 if __name__ == "__main__":
# ----> 2         main()
#       3
#
# <ipython-input-9-7942aec1e9a3> in main()
#       5
#       6         city, month, day = get_filters()
# ----> 7         df = load_data(city, month, day)
#       8
#       9         time_stats(df)
#
# <ipython-input-4-e744e629e1c7> in load_data(city, month, day)
#      12     """
#      13
# ---> 14     df = pd.read_csv(CITY_DATA[city])
# ...
